# %%
! pip install -e .
# Out:
# Obtaining file:///home/jovyan/layer-skip/mergekit
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for mergekit (pyproject.toml) ... done
#   Created wheel for mergekit: filename=mergekit-0.0.5.1-0.editable-py3-none-any.whl size=11499 sha256=f57b354623056b1af4fb23fee353c8ce812647f6aa2e5d484c5c5a3fa1194bb1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_d0hrjy9/wheels/3d/60/dc/aa1b0832f3aab7d1b86a601a2f7f88b647b11b925e52559e9f
# Successfully built mergekit
# ...
#   Attempting uninstall: mergekit
#     Found existing installation: mergekit 0.0.5.1
#     Uninstalling mergekit-0.0.5.1:
#       Successfully uninstalled mergekit-0.0.5.1
# ...

# %%
! mergekit-yaml /home/jovyan/layer-skip/PruneMe/slice_with_mergekit/slice_layer_skip_test.yaml /home/jovyan/layer-skip/model-checkpoint/layer_skip_1b_pruned_test
# Out:
# ...
# Fetching 8 files:   0%|                                   | 0/8 [00:00<?, ?it/s]
#
# generation_config.json: 100%|███████████████████| 126/126 [00:00<00:00, 577kB/s]
#
#
# original/consolidate_params.json: 100%|████████| 544/544 [00:00<00:00, 2.79MB/s]
#
# Fetching 8 files:  25%|██████▊                    | 2/8 [00:00<00:00, 11.23it/s]
#
# special_tokens_map.json: 100%|█████████████████| 296/296 [00:00<00:00, 1.84MB/s]
#
#
# original/params.json: 100%|████████████████| 9.67k/9.67k [00:00<00:00, 54.9MB/s]
#
#
# tokenizer_config.json:   0%|                        | 0.00/50.5k [00:00<?, ?B/s]
#
#
# tokenizer_config.json: 100%|███████████████| 50.5k/50.5k [00:00<00:00, 4.49MB/s]
#
#
#
# tokenizer.json:  61%|█████████████▍        | 10.5M/17.2M [00:00<00:00, 35.7MB/s]
#
#
# tokenizer.json: 100%|██████████████████████| 17.2M/17.2M [00:00<00:00, 37.6MB/s]
#
#
# model.safetensors:   0%|                            | 0.00/2.47G [00:00<?, ?B/s]
#
# ...
