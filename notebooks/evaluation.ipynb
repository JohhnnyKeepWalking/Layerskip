# %%
! cd /home/jovyan/layer-skip/lm-evaluation-harness

# %%
! pip install -e .
# Out:
# Obtaining file:///home/jovyan/layer-skip/lm-evaluation-harness
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for lm_eval (pyproject.toml) ... done
#   Created wheel for lm_eval: filename=lm_eval-0.4.5-0.editable-py3-none-any.whl size=19708 sha256=af0b2e538ac4e0c0b86f20a539e8def2612b319f8ed7ccb3ce1e9101e7bd488c
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yvz8tohq/wheels/99/d4/46/2bd6ad3dbdf19064d18f1ca4c972abd5e4d5e0100390ed5637
# Successfully built lm_eval
# ...
#   Attempting uninstall: lm_eval
#     Found existing installation: lm_eval 0.4.5
#     Uninstalling lm_eval-0.4.5:
#       Successfully uninstalled lm_eval-0.4.5
# ...

# %%
! lm_eval --model hf \
    --model_args pretrained=/home/jovyan/layer-skip/model-checkpoint/layer_skip_1b_pruned_test \
    --tasks boolq,hellaswag,openbookqa \
    --device cuda:0 \
    --output_path "/home/jovyan/layer-skip/lm-evaluation-harness/output/layer_skip_1b_pruned_test" \
    --batch_size 16
